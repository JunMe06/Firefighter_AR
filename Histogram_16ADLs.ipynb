# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics

import os
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
import pandas as pd

walk_fw = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\walkForward.xlsx')
walk_bw = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\walkBackward.xlsx')
jog_run = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\jog&run.xlsx')
squat_down = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\squatDown.xlsx')

bending = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\bend.xlsx')
bend_pickup = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\bendPickup.xlsx')
limp = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\limp.xlsx')
stumble = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\stumble.xlsx')

trip_over = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\tripOver.xlsx')
cough_sneeze = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\cough&sneeze.xlsx')
sit_chair = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\sitChair.xlsx')
sit_sofa = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\sitSofa.xlsx')

sit_air = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\sitAir.xlsx')
sit_bed = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\sitBed.xlsx')
lying_bed = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\lyingBed.xlsx')
rising_bed = pd.read_excel(r'F:\Program\OneDrive\Máy tính\16ADLs excel\risingBed.xlsx')

# %%
G = 9.81

X_walk_fw = walk_fw['Acc_X'][0:375].div(G)
X_walk_bw = walk_bw['Acc_X'][0:375].div(G)
X_jog_run = jog_run['Acc_X'][0:375].div(G)
X_squat_down = squat_down['Acc_X'][0:375].div(G)

X_bending = bending['Acc_X'][0:375].div(G)
X_bend_pickup = bend_pickup['Acc_X'][0:375].div(G)
X_limp = limp['Acc_X'][0:375].div(G)
X_stumble = stumble['Acc_X'][0:375].div(G)

X_trip_over = trip_over['Acc_X'][0:375].div(G)
X_cough_sneeze = cough_sneeze['Acc_X'][0:375].div(G)
X_sit_chair = sit_chair['Acc_X'][0:375].div(G)
X_sit_sofa = sit_sofa['Acc_X'][0:375].div(G)

X_sit_air = sit_air['Acc_X'][0:375].div(G)
X_sit_bed = sit_bed['Acc_X'][0:375].div(G)
X_lying_bed = lying_bed['Acc_X'][0:375].div(G)
X_rising_bed = rising_bed['Acc_X'][0:375].div(G)

# %%
# histogram
# X-asis

X_walk_fw.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')   
                    #bin: số khoảng giá trị được chia ra từ range, có bao nhiêu counts xuất hiện trong khoảng đó
plt.title('walk_fw')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(2)
X_walk_bw.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('walk_bw')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(3) 
X_jog_run.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('jog_run')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(4) 
X_squat_down.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('squat_down')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])
# Out:
# Text(0.5, 1.0, 'walk_fw')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'walk_bw')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'jog_run')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'squat_down')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)

# %%
X_bending.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')   
                    #bin: số khoảng giá trị được chia ra từ range, có bao nhiêu counts xuất hiện trong khoảng đó
plt.title('bending')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(2)
X_bend_pickup.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('bend_pickup')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(3) 
X_limp.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('limp')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(4) 
X_stumble.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('stumble')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])
# Out:
# Text(0.5, 1.0, 'bending')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'bend_pickup')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'limp')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'stumble')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)

# %%
X_trip_over.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')   
                    #bin: số khoảng giá trị được chia ra từ range, có bao nhiêu counts xuất hiện trong khoảng đó
plt.title('trip_over')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(2)
X_cough_sneeze.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('cough_sneeze')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(3) 
X_sit_chair.plot.hist(grid=True, bins=20, range = [-0.5, 2.5],  rwidth=0.8, color='#607c8e')
plt.title('sit_chair')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(4) 
X_sit_sofa.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('sit_sofa')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])
# Out:
# Text(0.5, 1.0, 'trip_over')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'cough_sneeze')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'sit_chair')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'sit_sofa')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)

# %%
X_sit_air.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')   
                    #bin: số khoảng giá trị được chia ra từ range, có bao nhiêu counts xuất hiện trong khoảng đó
plt.title('sit_air')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(2)
X_sit_bed.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('sit_bed')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(3) 
X_lying_bed.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('lying_bed')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])

plt.figure(4) 
X_rising_bed.plot.hist(grid=True, bins=20, range = [-0.5, 2.5], rwidth=0.8, color='#607c8e')
plt.title('rising_bed')
plt.ylabel('COUNTS')
plt.xlabel('ACC VALUE (g)')
plt.ylim([0, 400])
# Out:
# Text(0.5, 1.0, 'sit_air')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'sit_bed')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'lying_bed')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
# Text(0.5, 1.0, 'rising_bed')
# Text(0, 0.5, 'COUNTS')
# Text(0.5, 0, 'ACC VALUE (g)')
# (0, 400)
